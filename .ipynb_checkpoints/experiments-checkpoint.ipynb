# %%
import numpy as np

import fairnmf
from utils import load_dataset, exp_standard_NMF, exp_Fairer_NMF, make_plots

# %%
SAVE_PLOT = True
SAVE_DATA = False
LOAD_DATA = True

# %%
data_20n = load_dataset('20n')

# %%
if not LOAD_DATA:

    s_losses_20n, s_errors_20n, s_grperr_20n = exp_standard_NMF(data_20n)
    
    if SAVE_DATA:
        np.save(f"data/20n_s_losses.npy", s_losses_20n)
        np.save(f"data/20n_s_errors.npy", s_errors_20n)
        np.save(f"data/20n_s_grperr.npy", s_grperr_20n)
        
    f_losses_20n_mu, f_errors_20n_mu, f_times_20n_mu = exp_Fairer_NMF(data_20n, 'mu')

    if SAVE_DATA:
        np.save(f"data/20n_f_losses_MU.npy", f_losses_20n_mu)
        np.save(f"data/20n_f_errors_MU.npy", f_errors_20n_mu)
        np.save(f"data/20n_f_times_MU.npy",  f_times_20n_mu)
    
    f_losses_20n_am, f_errors_20n_am, f_times_20n_am = exp_Fairer_NMF(data_20n, 'am')
    
    if SAVE_DATA:
        np.save(f"data/20n_f_losses_AM.npy", f_losses_20n_am)
        np.save(f"data/20n_f_errors_AM.npy", f_errors_20n_am)
        np.save(f"data/20n_f_times_AM.npy",  f_times_20n_am)

# %%
if LOAD_DATA:
    s_losses_20n    = np.load("data/20n_s_losses.npy")
    s_errors_20n    = np.load("data/20n_s_errors.npy")
    s_grperr_20n    = np.load("data/20n_s_grperr.npy")

    f_losses_20n_mu = np.load("data/20n_f_losses_MU.npy")
    f_errors_20n_mu = np.load("data/20n_f_errors_MU.npy")
    f_times_20n_mu  = np.load("data/20n_f_times_MU.npy")

    f_losses_20n_am = np.load("data/20n_f_losses_AM.npy")
    f_errors_20n_am = np.load("data/20n_f_errors_AM.npy")
    f_times_20n_am  = np.load("data/20n_f_times_AM.npy")

# %%
if SAVE_PLOT:
    file_names = ['plots/20n_snmf_loss.pdf', 'plots/20n_fnmf_loss_MU.pdf', 'plots/20n_fnmf_loss_AM.pdf']
else:
    file_names = None

make_plots(data_20n, [s_losses_20n, f_losses_20n_mu, f_losses_20n_am], 'Loss', file_names)

# %%
if SAVE_PLOT:
    file_names = ['plots/20n_snmf_err.pdf', 'plots/20n_snmf_grperr.pdf', 'plots/20n_fnmf_err_MU.pdf', 'plots/20n_fnmf_err_AM.pdf']
else:
    file_names = None
    
make_plots(data_20n, [s_errors_20n, s_grperr_20n, f_errors_20n_mu, f_errors_20n_am], 'Relative Error (%)', file_names)

# %%
data_hd = load_dataset("hd")

# %%
if not LOAD_DATA:

    s_losses_hd, s_errors_hd, s_grperr_hd = exp_standard_NMF(data_hd)

    if SAVE_DATA:
        np.save(f"data/hd_s_losses.npy", s_losses_hd)
        np.save(f"data/hd_s_errors.npy", s_errors_hd)
        np.save(f"data/hd_s_grperr.npy", s_grperr_hd)
    
    f_losses_hd_mu, f_errors_hd_mu, f_times_hd_mu = exp_Fairer_NMF(data_hd, 'mu')

    
    if SAVE_DATA:
        np.save(f"data/hd_f_losses_MU.npy", f_losses_hd_mu)
        np.save(f"data/hd_f_errors_MU.npy", f_errors_hd_mu)
        np.save(f"data/hd_f_times_MU.npy",  f_times_hd_mu)
    
    f_losses_hd_am, f_errors_hd_am, f_times_hd_am = exp_Fairer_NMF(data_hd, 'am')
    
    if SAVE_DATA:
        np.save(f"data/hd_f_losses_AM.npy", f_losses_hd_am)
        np.save(f"data/hd_f_errors_AM.npy", f_errors_hd_am)
        np.save(f"data/hd_f_times_AM.npy",  f_times_hd_am)

# %%
if LOAD_DATA:
    s_losses_hd    = np.load("data/hd_s_losses.npy")
    s_errors_hd    = np.load("data/hd_s_errors.npy")
    s_grperr_hd    = np.load("data/hd_s_grperr.npy")

    f_losses_hd_mu = np.load("data/hd_f_losses_MU.npy")
    f_errors_hd_mu = np.load("data/hd_f_errors_MU.npy")
    f_times_hd_mu  = np.load("data/hd_f_times_MU.npy")

    f_losses_hd_am = np.load("data/hd_f_losses_AM.npy")
    f_errors_hd_am = np.load("data/hd_f_errors_AM.npy")
    f_times_hd_am  = np.load("data/hd_f_times_AM.npy")

# %%
if SAVE_PLOT:
    file_names = ['plots/hd_snmf_loss.pdf', 'plots/hd_fnmf_loss_MU.pdf', 'plots/hd_fnmf_loss_AM.pdf']
else:
    file_names = None

make_plots(data_hd, [s_losses_hd, f_losses_hd_mu, f_losses_hd_am], 'Loss', file_names)

# %%
if SAVE_PLOT:
    file_names = ['plots/hd_snmf_err.pdf', 'plots/hd_snmf_grperr.pdf', 'plots/hd_fnmf_err_MU.pdf', 'plots/hd_fnmf_err_AM.pdf']
else:
    file_names = None
    
make_plots(data_hd, [s_errors_hd, s_grperr_hd, f_errors_hd_mu, f_errors_hd_am], 'Relative Error (%)', file_names)

# %%
data_ortho1 = load_dataset("ortho1")

# %%
if not LOAD_DATA:

    s_losses_ortho1, s_errors_ortho1, s_grperr_ortho1 = exp_standard_NMF(data_ortho1)

    if SAVE_DATA:
        np.save(f"data/ortho1_s_losses.npy", s_losses_ortho1)
        np.save(f"data/ortho1_s_errors.npy", s_errors_ortho1)
        np.save(f"data/ortho1_s_grperr.npy", s_grperr_ortho1)
    
    f_losses_ortho1_mu, f_errors_ortho1_mu, f_times_ortho1_mu = exp_Fairer_NMF(data_ortho1, 'mu')
    
    if SAVE_DATA:
        np.save(f"data/ortho1_f_losses_MU.npy", f_losses_ortho1_mu)
        np.save(f"data/ortho1_f_errors_MU.npy", f_errors_ortho1_mu)
        np.save(f"data/ortho1_f_times_MU.npy",  f_times_ortho1_mu)
    
    f_losses_ortho1_am, f_errors_ortho1_am, f_times_ortho1_am = exp_Fairer_NMF(data_ortho1, 'am')
    
    if SAVE_DATA:
        np.save(f"data/ortho1_f_losses_AM.npy", f_losses_ortho1_am)
        np.save(f"data/ortho1_f_errors_AM.npy", f_errors_ortho1_am)
        np.save(f"data/ortho1_f_times_AM.npy",  f_times_ortho1_am)

# %%
if LOAD_DATA:
    s_losses_ortho1    = np.load("data/ortho1_s_losses.npy")
    s_errors_ortho1    = np.load("data/ortho1_s_errors.npy")
    s_grperr_ortho1    = np.load("data/ortho1_s_grperr.npy")

    f_losses_ortho1_mu = np.load("data/ortho1_f_losses_MU.npy")
    f_errors_ortho1_mu = np.load("data/ortho1_f_errors_MU.npy")
    f_times_ortho1_mu  = np.load("data/ortho1_f_times_MU.npy")

    f_losses_ortho1_am = np.load("data/ortho1_f_losses_AM.npy")
    f_errors_ortho1_am = np.load("data/ortho1_f_errors_AM.npy")
    f_times_ortho1_am  = np.load("data/ortho1_f_times_AM.npy")

# %%
if SAVE_PLOT:
    file_names = [
        'plots/ortho1_snmf_loss.pdf',
        'plots/ortho1_fnmf_loss_MU.pdf',
        'plots/ortho1_fnmf_loss_AM.pdf',
    ]
else:
    file_names = None


losses = [
    s_losses_ortho1,
    f_losses_ortho1_mu,
    f_losses_ortho1_am,
]

make_plots(data_ortho1, losses, 'Loss', file_names)

# %%
if SAVE_PLOT:
    file_names = [
        'plots/ortho1_snmf_err.pdf',
        'plots/ortho1_snmf_grperr.pdf',
        'plots/ortho1_fnmf_err_MU.pdf',
        'plots/ortho1_fnmf_err_AM.pdf',
    ]
else:
    file_names = None

errors = [
    s_errors_ortho1,
    s_grperr_ortho1,
    f_errors_ortho1_mu,
    f_errors_ortho1_am,
]
    
make_plots(data_ortho1, errors, 'Relative Error (%)', file_names)

# %%
data_ortho2 = load_dataset("ortho2")

# %%
if not LOAD_DATA:

    s_losses_ortho2, s_errors_ortho2, s_grperr_ortho2 = exp_standard_NMF(data_ortho2)

    if SAVE_DATA:
        np.save(f"data/ortho2_s_losses.npy", s_losses_ortho2)
        np.save(f"data/ortho2_s_errors.npy", s_errors_ortho2)
        np.save(f"data/ortho2_s_grperr.npy", s_grperr_ortho2)
    
    f_losses_ortho2_mu, f_errors_ortho2_mu, f_times_ortho2_mu = exp_Fairer_NMF(data_ortho2, 'mu')

    if SAVE_DATA:
        np.save(f"data/ortho2_f_losses_MU.npy", f_losses_ortho2_mu)
        np.save(f"data/ortho2_f_errors_MU.npy", f_errors_ortho2_mu)
        np.save(f"data/ortho2_f_times_MU.npy",  f_times_ortho2_mu)
    
    f_losses_ortho2_am, f_errors_ortho2_am, f_times_ortho2_am = exp_Fairer_NMF(data_ortho2, 'am')
    
    if SAVE_DATA:
        np.save(f"data/ortho2_f_losses_AM.npy", f_losses_ortho2_am)
        np.save(f"data/ortho2_f_errors_AM.npy", f_errors_ortho2_am)
        np.save(f"data/ortho2_f_times_AM.npy",  f_times_ortho2_am)

# %%
if LOAD_DATA:
    s_losses_ortho2    = np.load("data/ortho2_s_losses.npy")
    s_errors_ortho2    = np.load("data/ortho2_s_errors.npy")
    s_grperr_ortho2    = np.load("data/ortho2_s_grperr.npy")

    f_losses_ortho2_mu = np.load("data/ortho2_f_losses_MU.npy")
    f_errors_ortho2_mu = np.load("data/ortho2_f_errors_MU.npy")
    f_times_ortho2_mu  = np.load("data/ortho2_f_times_MU.npy")

    f_losses_ortho2_am = np.load("data/ortho2_f_losses_AM.npy")
    f_errors_ortho2_am = np.load("data/ortho2_f_errors_AM.npy")
    f_times_ortho2_am  = np.load("data/ortho2_f_times_AM.npy")

# %%
if SAVE_PLOT:
    file_names = [
        'plots/ortho2_snmf_loss.pdf',
        'plots/ortho2_fnmf_loss_MU.pdf',
        'plots/ortho2_fnmf_loss_AM.pdf',
    ]
else:
    file_names = None


losses = [
    s_losses_ortho2,
    f_losses_ortho2_mu,
    f_losses_ortho2_am,
]

make_plots(data_ortho2, losses, 'Loss', file_names)

# %%
if SAVE_PLOT:
    file_names = [
        'plots/ortho2_snmf_err.pdf',
        'plots/ortho2_snmf_grperr.pdf',
        'plots/ortho2_fnmf_err_MU.pdf',
        'plots/ortho2_fnmf_err_AM.pdf',
    ]
else:
    file_names = None

errors = [
    s_errors_ortho2,
    s_grperr_ortho2,
    f_errors_ortho2_mu,
    f_errors_ortho2_am,
]
    
make_plots(data_ortho2, errors, 'Relative Error (%)', file_names)

# %% [markdown]
# ## MU convergence plots

# %%
data_ortho1 = load_dataset("ortho1")
rank_ortho1 = 3

# %%
convergence_losses_ortho1_decaying_lr, convergence_ortho1_errors_decaying_lr = exp_MU_convergence(data_ortho1, rank_ortho1, 'decaying_lr')
convergence_losses_ortho1_largest, convergence_ortho1_errors_largest = exp_MU_convergence(data_ortho1, rank_ortho1, 'largest')

# %%
if SAVE_PLOT:
    file_names = [
        'plots/convergence_losses_ortho1_decaying_lr.pdf',
        'plots/convergence_losses_ortho1_largest.pdf',
    ]
else:
    file_names = None

losses = [
    convergence_losses_ortho1_decaying_lr,
    convergence_losses_ortho1_largest,
]
    
make_plots(data_ortho1, losses, 'Loss', file_names, xaxis='iter', use_markers=False)

# %%
data_ortho2 = load_dataset("ortho2")
rank_ortho2 = 5

# %%
convergence_losses_ortho2_decaying_lr, convergence_ortho2_errors_decaying_lr = exp_MU_convergence(data_ortho2, rank_ortho2, 'decaying_lr')
convergence_losses_ortho2_largest, convergence_ortho2_errors_largest = exp_MU_convergence(data_ortho2, rank_ortho2, 'largest')

# %%
if SAVE_PLOT:
    file_names = [
        'plots/convergence_losses_ortho2_decaying_lr.pdf',
        'plots/convergence_losses_ortho2_largest.pdf',
    ]
else:
    file_names = None

losses = [
    convergence_losses_ortho2_decaying_lr,
    convergence_losses_ortho2_largest,
]
    
make_plots(data_ortho2, losses, 'Loss', file_names, xaxis='iter', use_markers=False)
